# %% [markdown]
# # Collab preliminaries

# %%
# !nvcc --version
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2020 NVIDIA Corporation
# Built on Wed_Jul_22_19:09:09_PDT_2020
# Cuda compilation tools, release 11.0, V11.0.221
# Build cuda_11.0_bu.TC445_37.28845127_0

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !nvidia-smi
# Out:
# Sat May 15 06:07:15 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 465.19.01    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   37C    P8    10W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %% [markdown]
# # Get the code and models

# %%
# !git clone https://github.com/Rudrabha/Wav2Lip.git
# Out:
# fatal: destination path 'Wav2Lip' already exists and is not an empty directory.

# %%
# !ls
# Out:
# gdrive	sample_data  Wav2Lip

# %%
# !cp "/content/gdrive/MyDrive/Wav2lip/wav2lip.pth" /content/Wav2Lip/checkpoints/

# %% [markdown]
# # Get the pre-requisites

# %%
# !pip uninstall tensorflow tensorflow-gpu
# Out:
# WARNING: Skipping tensorflow as it is not installed.
# WARNING: Skipping tensorflow-gpu as it is not installed.

# %%
# !cd Wav2Lip && pip install -r requirements.txt

# %%
# !wget "https://www.adrianbulat.com/downloads/python-fan/s3fd-619a316812.pth" -O "Wav2Lip/face_detection/detection/sfd/s3fd.pth"
# Out:
# --2021-05-15 06:15:05--  https://www.adrianbulat.com/downloads/python-fan/s3fd-619a316812.pth
# Resolving www.adrianbulat.com (www.adrianbulat.com)... 45.136.29.207
# Connecting to www.adrianbulat.com (www.adrianbulat.com)|45.136.29.207|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 89843225 (86M) [application/octet-stream]
# Saving to: ‘Wav2Lip/face_detection/detection/sfd/s3fd.pth’
#
# Wav2Lip/face_detect 100%[===================>]  85.68M  26.2MB/s    in 3.3s
#
# 2021-05-15 06:15:09 (26.2 MB/s) - ‘Wav2Lip/face_detection/detection/sfd/s3fd.pth’ saved [89843225/89843225]

# %% [markdown]
# # Now lets try!

# %%
# !cp "/content/gdrive/My Drive/Wav2Lip/speech.mp4" "/content/gdrive/My Drive/Wav2Lip/polly.wav" sample_data/
# !cp "/content/gdrive/My Drive/Wav2Lip/elon1.mp4" "/content/gdrive/My Drive/Wav2Lip/input2.wav" sample_data/

# !ls sample_data/
# Out:
# anscombe.json		      input2.wav       mnist_train_small.csv
# barack1.mp4		      input_audio.wav  README.md
# california_housing_test.csv   inputaudio.wav   test1.mp4
# california_housing_train.csv  input_video.mp4  test2.mp4
# elon1.mp4		      inputvideo.mp4
# input2.mp4		      mnist_test.csv

# %%
# !cd Wav2Lip && python inference.py --checkpoint_path checkpoints/wav2lip.pth --face "../sample_data/elon1.mp4" --audio "../sample_data/input2.wav"
# Out:
# Using cuda for inference.
# Reading video frames...
# Number of frames available for inference: 449
# (80, 4362)
# Length of mel chunks: 1358
#   0% 0/11 [00:00<?, ?it/s]
#   0% 0/29 [00:00<?, ?it/s]THCudaCheck FAIL file=/pytorch/aten/src/THC/THCGeneral.cpp line=383 error=11 : invalid argument
#   0% 0/29 [00:00<?, ?it/s]
# Recovering from OOM error; New batch size: 8
#
#   0% 0/57 [00:00<?, ?it/s]
#   2% 1/57 [00:04<04:10,  4.47s/it]
#   4% 2/57 [00:05<03:01,  3.30s/it]
#   5% 3/57 [00:05<02:13,  2.47s/it]
#   7% 4/57 [00:06<01:40,  1.90s/it]
#   9% 5/57 [00:06<01:17,  1.49s/it]
#  11% 6/57 [00:07<01:01,  1.21s/it]
#  12% 7/57 [00:07<00:50,  1.02s/it]
#  14% 8/57 [00:08<00:43,  1.14it/s]
#  16% 9/57 [00:08<00:37,  1.28it/s]
#  18% 10/57 [00:09<00:33,  1.40it/s]
#  19% 11/57 [00:10<00:30,  1.50it/s]
#  21% 12/57 [00:10<00:28,  1.58it/s]
#  23% 13/57 [00:11<00:27,  1.63it/s]
#  25% 14/57 [00:11<00:25,  1.68it/s]
#  26% 15/57 [00:12<00:24,  1.71it/s]
# ...

# %%
# use the "files" button on the left to download the result in the Wav2Lip/results/ folder.

# %% [markdown]
# ## **Variations to try**

# %% [markdown]
# 1.   Use more padding to include the chin region

# %%
# !cd Wav2Lip && python inference.py --checkpoint_path checkpoints/wav2lip.pth --face "../sample_data/elon.mp4" --audio "../sample_data/Intoxicated.wav" --pads 0 20 0 0
# Out:
# Traceback (most recent call last):
#   File "inference.py", line 2, in <module>
#     import numpy as np
#   File "/usr/local/lib/python3.7/dist-packages/numpy/__init__.py", line 142, in <module>
#     from . import core
#   File "/usr/local/lib/python3.7/dist-packages/numpy/core/__init__.py", line 76, in <module>
#     from . import records as rec
#   File "<frozen importlib._bootstrap>", line 983, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 967, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 677, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 724, in exec_module
#   File "<frozen importlib._bootstrap_external>", line 812, in get_code
#   File "<frozen importlib._bootstrap_external>", line 953, in path_stats
#   File "<frozen importlib._bootstrap_external>", line 81, in _path_stat
# KeyboardInterrupt

# %% [markdown]
# 2.   Use resize_factor to reduce the video resolution, as there is a change you might get better results for lower resolution videos. Why? Because the model was trained on low resolution faces.

# %%
# !cd Wav2Lip && python inference.py --checkpoint_path checkpoints/wav2lip.pth --face "../sample_data/inputvid.mp4" --audio "../sample_data/Intoxicated.wav" --resize_factor 2
# Out:
# Using cuda for inference.
# Reading video frames...
# Number of frames available for inference: 150
# (80, 20230)
# Length of mel chunks: 6319
#   0% 0/50 [00:00<?, ?it/s]
#   0% 0/10 [00:00<?, ?it/s]
#  10% 1/10 [00:11<01:40, 11.13s/it]
#  20% 2/10 [00:11<01:03,  7.96s/it]
#  30% 3/10 [00:12<00:40,  5.74s/it]
#  40% 4/10 [00:12<00:25,  4.18s/it]
#  50% 5/10 [00:13<00:15,  3.09s/it]
#  60% 6/10 [00:13<00:09,  2.33s/it]
#  70% 7/10 [00:14<00:05,  1.79s/it]
#  80% 8/10 [00:14<00:02,  1.42s/it]
#  90% 9/10 [00:15<00:01,  1.16s/it]
# 100% 10/10 [00:23<00:00,  2.37s/it]
# Load checkpoint from: checkpoints/wav2lip.pth
# Model loaded
# 100% 50/50 [01:20<00:00,  1.60s/it]
# ffmpeg version 3.4.8-0ubuntu0.2 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 7 (Ubuntu 7.5.0-3ubuntu1~18.04)
# ...
